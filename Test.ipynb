# %%
import pandas as pd

Genshin_Banner = pd.read_csv('genshin_banner_history_eurogamer.csv')
Genshin_Banner
# Out:
#                    Banner Name    5-Star Character  \
# 0            Ballad in Goblets               Venti
# 1              Sparkling Steps                Klee
# 2        Farewell of Snezhnaya  Tartaglia (Childe)
# 3          Gentry of Hermitage             Zhongli
# 4          Secretum Secretorum              Albedo
# ..                         ...                 ...
# 127  The Hearth's Ashen Shadow          Arlecchino
# 128    Dawn's Drifting Reverie              Mizuki
# 129    Romaritime Meluserenity           Sigewinne
# 130     Chanson of Many Waters              Furina
# 131        Tempestuous Destiny         Wriothesley
#
#                4-Star Characters                                Banner Dates
# 0     Barbara, Fischl, Xiangling  28th September, 2020 to 18th October, 2020
# 1       Noelle, Sucrose, Xingqiu   20th October, 2020 to 10th November, 2020
# 2       Beidou, Diona, Ningguang   11th November, 2020 to 1st December, 2020
# ...

# %%
HSR_Banner = pd.read_csv('hsr_banner_history_eurogamer.csv')
HSR_Banner
# Out:
#                    Banner Name 5-Star Character            4-Star Characters  \
# 0        Butterfly on Swordtip            Seele          Hook, Natasha, Pela
# 1      Swirl of Heavenly Spear        Jing Yuan  March 7th, Sushang, Tingyun
# 2                Contract Zero      Silver Wolf       Asta, Dan Heng, Serval
# 3                 Laic Pursuit           Luocha        Pela, Qingque, Yukong
# 4                  A Lost Soul            Blade      Arlan, Natasha, Sushang
# ..                         ...              ...                          ...
# 59           Indelible Coterie      Silver Wolf      Hanya, Sushang, Tingyun
# 60       Back to Fons et Origo          Tribbie        Guinaifen, Hook, Lynx
# 61  Earth Hurled, Ether Curled            Yunli        Guinaifen, Hook, Lynx
# 62             Fiery Lionheart            Mydei        Arlan, Natasha, Xueyi
# 63              Bloom in Gloom           Huohuo        Arlan, Natasha, Xueyi
#
# ...
